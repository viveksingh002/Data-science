# %%
import numpy as np

scores = np.random.randint(0, 100, size=50)

print("Scores:")
print(scores)

print("\nMean:", np.mean(scores))
print("Median:", np.median(scores))
print("Highest:", np.max(scores))
print("Lowest:", np.min(scores))
print("Standard Deviation:", np.std(scores))

print("\n25th Percentile:", np.percentile(scores, 25))
print("50th Percentile:", np.percentile(scores, 50))
print("75th Percentile:", np.percentile(scores, 75))

failed = scores[scores < 40]
distinction = scores[scores > 85]

print("\nFailed Students:")
print(failed)

print("\nDistinction Students:")
print(distinction)

normalized = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))

print("\nNormalized Scores:")
print(normalized)

reshaped = scores.reshape(5, 10)

print("\nReshaped Array:")
print(reshaped)

subject_avg = np.mean(reshaped, axis=1)

print("\nSubject-wise Averages:")
print(subject_avg)

theory = np.random.randint(0, 100, size=50)
practical = np.random.randint(0, 100, size=50)

final_scores = (0.4 * theory) + (0.6 * practical)

print("\nWeighted Final Scores:")
print(final_scores)
# Out:
# Scores:
# [86 42 92 64 61 33 53 19  5 35 87 37 25 47 78 59 74 68 62 66  6 58 78 95
#  34 36 12 54 46 61 11  3 47 59 99 72 66 15 70 16  3 54 89 82 82 43 10 33
#  29  9]
#
# Mean: 49.3
# Median: 53.5
# Highest: 99
# Lowest: 3
# Standard Deviation: 27.465068723744345
#
# 25th Percentile: 30.0
# 50th Percentile: 53.5
# 75th Percentile: 69.5
#
# Failed Students:
# [33 19  5 35 37 25  6 34 36 12 11  3 15 16  3 10 33 29  9]
#
# Distinction Students:
# [86 92 87 95 99 89]
#
# Normalized Scores:
# [0.86458333 0.40625    0.92708333 0.63541667 0.60416667 0.3125
#  0.52083333 0.16666667 0.02083333 0.33333333 0.875      0.35416667
#  0.22916667 0.45833333 0.78125    0.58333333 0.73958333 0.67708333
#  0.61458333 0.65625    0.03125    0.57291667 0.78125    0.95833333
#  0.32291667 0.34375    0.09375    0.53125    0.44791667 0.60416667
#  0.08333333 0.         0.45833333 0.58333333 1.         0.71875
#  0.65625    0.125      0.69791667 0.13541667 0.         0.53125
#  0.89583333 0.82291667 0.82291667 0.41666667 0.07291667 0.3125
#  0.27083333 0.0625    ]
#
# Reshaped Array:
# [[86 42 92 64 61 33 53 19  5 35]
#  [87 37 25 47 78 59 74 68 62 66]
#  [ 6 58 78 95 34 36 12 54 46 61]
#  [11  3 47 59 99 72 66 15 70 16]
#  [ 3 54 89 82 82 43 10 33 29  9]]
#
# Subject-wise Averages:
# [49.  60.3 48.  45.8 43.4]
#
# Weighted Final Scores:
# [32.4 69.6 55.2 60.2 54.6 34.4 93.6 30.6 69.4 54.6 33.8 66.4 48.6  0.8
#  20.4 27.8 57.  45.2 48.2 76.  41.4 91.8 52.8 50.2 64.  53.6 12.4 25.
#  81.2 55.8 23.  70.4 44.  63.  47.4 54.8 50.6  5.6 34.  27.  30.8 44.
#  65.8 15.8 67.4 83.6 69.6 74.6 46.8 54.4]
